# %%
import visuals
# %matplotlib inline

# %%
visuals.plot_logs('log_level0.txt', 'Level 0 Naive Opponent')

# %%
visuals.plot_logs('log_level2.txt', 'Level 2 Naive Opponent')

# %%
visuals.plot_logs('log_level3.txt', 'Level 3 Naive Opponent')

# %%
visuals.plot_logs('log_self_play_level3.txt', 'Level 3 Naive Opponent')
